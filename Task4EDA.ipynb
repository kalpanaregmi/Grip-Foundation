# %% [markdown]
# <a href="https://colab.research.google.com/github/SB2507/The-Sparks-Foundation/blob/main/Task4EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
# **Kalpana Regmi**
# **The Sparks Foundation**
#
# **Task 4** : Perform 'Exploratory Data Analysis' on 'Global Terrorism' dataset

# %%
 from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Loading the datset

# %%
df=pd.read_csv("/content/drive/MyDrive/Spark/globalterrorismdb_0718dist.csv", encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  1.970000e+11   1970       7     2  ...        0         0       0      NaN
# 1  1.970000e+11   1970       0     0  ...        1         1       1      NaN
# 2  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 3  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 4  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 181686  2.017120e+11   2017      12    31  ...        0         0       0      NaN
# 181687  2.017120e+11   2017      12    31  ...       -9         1       1      NaN
# 181688  2.017120e+11   2017      12    31  ...        0         0       0      NaN
# 181689  2.017120e+11   2017      12    31  ...       -9         0      -9      NaN
# 181690  2.017120e+11   2017      12    31  ...       -9         0      -9      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
df.count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate      9239
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related        25038
# Length: 135, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325955e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991020e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009020e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014080e+11    2014.000000  ...       0.000000       0.000000
# max    2.017120e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
missing_percentage = df.isnull().sum()*100/len(df)
missing_percentage
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
df.dropna(axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# extended           0
# country            0
# country_txt        0
# region             0
# region_txt         0
# vicinity           0
# crit1              0
# crit2              0
# crit3              0
# success            0
# suicide            0
# attacktype1        0
# attacktype1_txt    0
# targtype1          0
# targtype1_txt      0
# gname              0
# individual         0
# weaptype1          0
# weaptype1_txt      0
# property           0
# dbsource           0
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# dtype: int64

# %%
df.corr()
# Out:
#               eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid      1.000000  0.999996  0.002705  ... -0.133252 -0.077851 -0.175606
# iyear        0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth       0.002705  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday         0.018270  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended     0.091762  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# country     -0.135039 -0.135023 -0.006305  ...  0.067564  0.207281  0.153118
# region       0.401371  0.401384 -0.002999  ... -0.071917  0.043139 -0.047900
# vicinity     0.070647  0.070659 -0.004501  ...  0.015119 -0.008232  0.010325
# crit1        0.002018  0.001995  0.001568  ...  0.089888  0.015692  0.082288
# crit2        0.026216  0.026211  0.001734  ... -0.023829 -0.012980 -0.027752
# crit3       -0.016788 -0.016784  0.000176  ... -0.138251 -0.036112 -0.130216
# success     -0.082972 -0.082963 -0.002845  ...  0.059183 -0.014906  0.038245
# suicide      0.137742  0.137736  0.003071  ...  0.065882 -0.000879  0.057241
# attacktype1  0.074173  0.074153  0.006705  ...  0.077225  0.010632  0.088711
# targtype1    0.079080  0.079082 -0.000948  ... -0.058010 -0.043492 -0.054497
# individual   0.017939  0.017944 -0.001661  ... -0.048542  0.005490 -0.037488
# weaptype1   -0.011716 -0.011737  0.007863  ...  0.074702 -0.011652  0.084257
# property    -0.278927 -0.278916 -0.005816  ...  0.047609  0.022058  0.065701
# INT_LOG     -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO    -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC    -0.077851 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY     -0.175606 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(x=df['iyear'])
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('Increase in Terror',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
sns.countplot(x=df['iyear'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('Increase in Terror',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Region')
plt.title('Country wise Attack',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country wise Attack')

# %%
sns.countplot(x=df['region_txt'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Region')
# Out:
# Text(0.5, 0, 'Attack Region')

# %%
sns.barplot(x=df['attacktype1_txt'].value_counts()[:20].index,y=df['attacktype1_txt'].value_counts()[:20].values)
plt.ylabel('Total Attack', fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Attack Type', fontsize=20)
plt.title('Attack types',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attack types')

# %% [markdown]
# ### Final Report
# **-Iraq ranked first on the global terrorism for their terrorist activity followed by Pakistan, Afganistan, India, and so on**
#
# **-Most targeted areas are private citizens and property, military, police, and so on.**
#
# **-Global terror attack deaths rose sharply starting year 2011**
#
# **-In conclusion with the ranking, Iraq suffered from most terrorist attacks in 2014, with the most deaths in that year**
